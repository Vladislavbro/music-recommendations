# %% [markdown]
# # 02 — Train gSASRec (Phase 1, Step H)
#
# Обучение per-user скорера на YAMBDA-50m, post-filter (`listen & played_ratio_pct>=50`, `min_pop>=5`).
#
# Запускается в Colab (A100 40GB) или локально на M4 Pro для smoke-теста (`subsample_users`).
#
# **Что делает:**
# 1. Загружает YAMBDA-50m через `src.data.yambda_loader`.
# 2. Применяет канонический пайплайн: `filter_listens → filter_min_popularity → build_item_id_to_idx → apply_item_remap → global_temporal_split`.
# 3. Запускает `train_gsasrec(train, val, TrainConfig(...))` из `src.scorer.train`.
# 4. Сохраняет `artifacts/gsasrec/best.pt` (checkpoint) + `metrics.csv` + `config.json`.
#
# **Что НЕ делает:** не считает топ-K кэш — это Step I, ноутбук `03_cache_user_scores.ipynb`.

# %% [markdown]
# ## 0. Setup

# %%
from google.colab import userdata

token = userdata.get('git')

# %%
# Colab bootstrap (раскомментировать, если запускаем в Colab):
# !git clone -b models-1 https://$token@github.com/Vladislavbro/music-recommendations.git
# %cd music-recommendations
# !pip install -r requirements.txt
# Out:
# Cloning into 'music-recommendations'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 122 (delta 35), reused 110 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (122/122), 553.69 KiB | 15.82 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# /content/music-recommendations

# %%
import os, sys
from pathlib import Path


PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))
print('project root:', PROJECT_ROOT)

import torch
print('torch:', torch.__version__, 'cuda:', torch.cuda.is_available())
# Out:
# project root: /content/music-recommendations
# torch: 2.10.0+cu128 cuda: True

# %%
from src.utils.seed import set_seed

set_seed(42)

# %% [markdown]
# ## 1. Load + canonical preprocessing

# %%
from src.data.yambda_loader import (
    load_yambda, filter_listens, filter_min_popularity,
    build_item_id_to_idx, apply_item_remap, subsample_users,
)
from src.data.splits import global_temporal_split, SplitConfig


HF_CACHE = os.environ.get('HF_DATASETS_CACHE', None)
raw = load_yambda('50m', cache_dir=HF_CACHE)['interactions']
print('raw events:', len(raw))
# Out:
# raw events: 47790449

# %%
# Smoke-режим (локальный M4 Pro): подсэмплируйте 500-1000 users перед сплитом.
# Полный run на Colab — оставить SMOKE = False.
SMOKE = False
SMOKE_N_USERS = 500

df = filter_listens(raw)
df = filter_min_popularity(df, min_count=5)
if SMOKE:
    df = subsample_users(df, n_users=SMOKE_N_USERS, seed=42)

item_id_to_idx = build_item_id_to_idx(df)
df = apply_item_remap(df, item_id_to_idx)
n_items = len(item_id_to_idx)
print(f'post-filter events: {len(df):,}, users: {df.uid.nunique():,}, items: {n_items:,}')

train, val, test = global_temporal_split(df, SplitConfig())
print(f'train: {len(train):,} ({train.uid.nunique():,} users)')
print(f'val:   {len(val):,} ({val.uid.nunique():,} users)')
print(f'test:  {len(test):,} ({test.uid.nunique():,} users)')
# Out:
# post-filter events: 28,819,720, users: 9,195, items: 276,305
# train: 28,524,373 (9,194 users)
# val:   139,455 (4,596 users)
# test:  153,140 (4,576 users)

# %% [markdown]
# ## 2. Train gSASRec

# %%
from src.scorer.train import TrainConfig, train_gsasrec

cfg = TrainConfig(
    n_items=n_items,
    max_seq_len=200,
    hidden_dim=64,   # было 256
    n_heads=2,       # было 4
    n_layers=2,      # было 2
    dropout=0,       # было 0.2, сделал как в яндексе
    n_neg=1,         # пары 1к1 вместо 1к512 для повтора яндекса
    mix_uniform=1,   # 1 для повтора яндекса, было 0.5
    gbce_t=0.75,     # ставим 1 вметсто 0.75, получается обычный BCE
    batch_size=128,
    eval_batch_size=64,
    lr=1e-3,
    n_epochs=60,
    early_stop_patience=15,   # было 5
    eval_k=10,
    seed=42,
    out_dir=str(PROJECT_ROOT / 'artifacts' / 'gsasrec'),
    device='cuda' if torch.cuda.is_available() else 'cpu',
    log_every_steps=12,
)
print(cfg)
# Out:
# TrainConfig(n_items=276305, max_seq_len=200, hidden_dim=64, n_heads=2, n_layers=2, dropout=0, n_neg=1, gbce_t=0.75, mix_uniform=1, batch_size=128, eval_batch_size=64, lr=0.001, weight_decay=0.0, n_epochs=60, early_stop_patience=15, seed=42, pop_smoothing=0.75, eval_k=10, log_every_steps=12, out_dir='/content/music-recommendations/artifacts/gsasrec', device='cuda')

# %%
result = train_gsasrec(train, val, cfg)
result
# Out:
#   epoch 0 step 12/72 loss=0.4333
#   epoch 0 step 24/72 loss=0.4328
#   epoch 0 step 36/72 loss=0.4286
#   epoch 0 step 48/72 loss=0.4193
#   epoch 0 step 60/72 loss=0.4067
#   epoch 0 step 72/72 loss=0.3928
# epoch 0: loss=0.3928 val_ndcg@10=0.0186 time=1.8s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 1 step 12/72 loss=0.2908
#   epoch 1 step 24/72 loss=0.2781
#   epoch 1 step 36/72 loss=0.2675
#   epoch 1 step 48/72 loss=0.2584
#   epoch 1 step 60/72 loss=0.2506
#   epoch 1 step 72/72 loss=0.2439
# epoch 1: loss=0.2439 val_ndcg@10=0.0183 time=0.6s
#   epoch 2 step 12/72 loss=0.1970
#   epoch 2 step 24/72 loss=0.1948
#   epoch 2 step 36/72 loss=0.1935
#   epoch 2 step 48/72 loss=0.1920
#   epoch 2 step 60/72 loss=0.1900
#   epoch 2 step 72/72 loss=0.1885
# epoch 2: loss=0.1885 val_ndcg@10=0.0176 time=0.6s
#   epoch 3 step 12/72 loss=0.1731
#   epoch 3 step 24/72 loss=0.1723
#   epoch 3 step 36/72 loss=0.1725
#   epoch 3 step 48/72 loss=0.1723
#   epoch 3 step 60/72 loss=0.1721
#   epoch 3 step 72/72 loss=0.1720
# epoch 3: loss=0.1720 val_ndcg@10=0.0183 time=0.6s
#   epoch 4 step 12/72 loss=0.1631
#   epoch 4 step 24/72 loss=0.1628
#   epoch 4 step 36/72 loss=0.1617
#   epoch 4 step 48/72 loss=0.1617
#   epoch 4 step 60/72 loss=0.1615
#   epoch 4 step 72/72 loss=0.1617
# epoch 4: loss=0.1617 val_ndcg@10=0.0202 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 5 step 12/72 loss=0.1509
#   epoch 5 step 24/72 loss=0.1517
#   epoch 5 step 36/72 loss=0.1520
#   epoch 5 step 48/72 loss=0.1528
#   epoch 5 step 60/72 loss=0.1526
#   epoch 5 step 72/72 loss=0.1525
# epoch 5: loss=0.1525 val_ndcg@10=0.0185 time=0.6s
#   epoch 6 step 12/72 loss=0.1429
#   epoch 6 step 24/72 loss=0.1438
#   epoch 6 step 36/72 loss=0.1439
#   epoch 6 step 48/72 loss=0.1436
#   epoch 6 step 60/72 loss=0.1441
#   epoch 6 step 72/72 loss=0.1440
# epoch 6: loss=0.1440 val_ndcg@10=0.0178 time=0.6s
#   epoch 7 step 12/72 loss=0.1361
#   epoch 7 step 24/72 loss=0.1355
#   epoch 7 step 36/72 loss=0.1350
#   epoch 7 step 48/72 loss=0.1352
#   epoch 7 step 60/72 loss=0.1350
#   epoch 7 step 72/72 loss=0.1351
# epoch 7: loss=0.1351 val_ndcg@10=0.0215 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 8 step 12/72 loss=0.1274
#   epoch 8 step 24/72 loss=0.1264
#   epoch 8 step 36/72 loss=0.1262
#   epoch 8 step 48/72 loss=0.1263
#   epoch 8 step 60/72 loss=0.1262
#   epoch 8 step 72/72 loss=0.1260
# epoch 8: loss=0.1260 val_ndcg@10=0.0237 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 9 step 12/72 loss=0.1165
#   epoch 9 step 24/72 loss=0.1169
#   epoch 9 step 36/72 loss=0.1171
#   epoch 9 step 48/72 loss=0.1170
#   epoch 9 step 60/72 loss=0.1169
#   epoch 9 step 72/72 loss=0.1170
# epoch 9: loss=0.1170 val_ndcg@10=0.0246 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 10 step 12/72 loss=0.1086
#   epoch 10 step 24/72 loss=0.1085
#   epoch 10 step 36/72 loss=0.1087
#   epoch 10 step 48/72 loss=0.1087
#   epoch 10 step 60/72 loss=0.1087
#   epoch 10 step 72/72 loss=0.1087
# epoch 10: loss=0.1087 val_ndcg@10=0.0290 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 11 step 12/72 loss=0.1010
#   epoch 11 step 24/72 loss=0.1002
#   epoch 11 step 36/72 loss=0.1005
#   epoch 11 step 48/72 loss=0.1004
#   epoch 11 step 60/72 loss=0.1002
#   epoch 11 step 72/72 loss=0.1004
# epoch 11: loss=0.1004 val_ndcg@10=0.0317 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 12 step 12/72 loss=0.0937
#   epoch 12 step 24/72 loss=0.0935
#   epoch 12 step 36/72 loss=0.0931
#   epoch 12 step 48/72 loss=0.0929
#   epoch 12 step 60/72 loss=0.0929
#   epoch 12 step 72/72 loss=0.0929
# epoch 12: loss=0.0929 val_ndcg@10=0.0376 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 13 step 12/72 loss=0.0868
#   epoch 13 step 24/72 loss=0.0868
#   epoch 13 step 36/72 loss=0.0866
#   epoch 13 step 48/72 loss=0.0864
#   epoch 13 step 60/72 loss=0.0863
#   epoch 13 step 72/72 loss=0.0861
# epoch 13: loss=0.0861 val_ndcg@10=0.0384 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 14 step 12/72 loss=0.0812
#   epoch 14 step 24/72 loss=0.0799
#   epoch 14 step 36/72 loss=0.0801
#   epoch 14 step 48/72 loss=0.0799
#   epoch 14 step 60/72 loss=0.0799
#   epoch 14 step 72/72 loss=0.0800
# epoch 14: loss=0.0800 val_ndcg@10=0.0425 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 15 step 12/72 loss=0.0750
#   epoch 15 step 24/72 loss=0.0746
#   epoch 15 step 36/72 loss=0.0747
#   epoch 15 step 48/72 loss=0.0745
#   epoch 15 step 60/72 loss=0.0745
#   epoch 15 step 72/72 loss=0.0745
# epoch 15: loss=0.0745 val_ndcg@10=0.0458 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 16 step 12/72 loss=0.0688
#   epoch 16 step 24/72 loss=0.0693
#   epoch 16 step 36/72 loss=0.0694
#   epoch 16 step 48/72 loss=0.0695
#   epoch 16 step 60/72 loss=0.0696
#   epoch 16 step 72/72 loss=0.0696
# epoch 16: loss=0.0696 val_ndcg@10=0.0456 time=0.6s
#   epoch 17 step 12/72 loss=0.0652
#   epoch 17 step 24/72 loss=0.0652
#   epoch 17 step 36/72 loss=0.0652
#   epoch 17 step 48/72 loss=0.0650
#   epoch 17 step 60/72 loss=0.0652
#   epoch 17 step 72/72 loss=0.0651
# epoch 17: loss=0.0651 val_ndcg@10=0.0492 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 18 step 12/72 loss=0.0606
#   epoch 18 step 24/72 loss=0.0609
#   epoch 18 step 36/72 loss=0.0611
#   epoch 18 step 48/72 loss=0.0611
#   epoch 18 step 60/72 loss=0.0610
#   epoch 18 step 72/72 loss=0.0611
# epoch 18: loss=0.0611 val_ndcg@10=0.0515 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 19 step 12/72 loss=0.0571
#   epoch 19 step 24/72 loss=0.0572
#   epoch 19 step 36/72 loss=0.0572
#   epoch 19 step 48/72 loss=0.0573
#   epoch 19 step 60/72 loss=0.0574
#   epoch 19 step 72/72 loss=0.0575
# epoch 19: loss=0.0575 val_ndcg@10=0.0563 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 20 step 12/72 loss=0.0543
#   epoch 20 step 24/72 loss=0.0545
#   epoch 20 step 36/72 loss=0.0544
#   epoch 20 step 48/72 loss=0.0544
#   epoch 20 step 60/72 loss=0.0545
#   epoch 20 step 72/72 loss=0.0544
# epoch 20: loss=0.0544 val_ndcg@10=0.0600 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 21 step 12/72 loss=0.0516
#   epoch 21 step 24/72 loss=0.0514
#   epoch 21 step 36/72 loss=0.0514
#   epoch 21 step 48/72 loss=0.0514
#   epoch 21 step 60/72 loss=0.0516
#   epoch 21 step 72/72 loss=0.0516
# epoch 21: loss=0.0516 val_ndcg@10=0.0559 time=0.6s
#   epoch 22 step 12/72 loss=0.0488
#   epoch 22 step 24/72 loss=0.0487
#   epoch 22 step 36/72 loss=0.0488
#   epoch 22 step 48/72 loss=0.0488
#   epoch 22 step 60/72 loss=0.0488
#   epoch 22 step 72/72 loss=0.0488
# epoch 22: loss=0.0488 val_ndcg@10=0.0609 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 23 step 12/72 loss=0.0463
#   epoch 23 step 24/72 loss=0.0463
#   epoch 23 step 36/72 loss=0.0464
#   epoch 23 step 48/72 loss=0.0465
#   epoch 23 step 60/72 loss=0.0465
#   epoch 23 step 72/72 loss=0.0465
# epoch 23: loss=0.0465 val_ndcg@10=0.0632 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 24 step 12/72 loss=0.0443
#   epoch 24 step 24/72 loss=0.0442
#   epoch 24 step 36/72 loss=0.0442
#   epoch 24 step 48/72 loss=0.0440
#   epoch 24 step 60/72 loss=0.0441
#   epoch 24 step 72/72 loss=0.0442
# epoch 24: loss=0.0442 val_ndcg@10=0.0640 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 25 step 12/72 loss=0.0420
#   epoch 25 step 24/72 loss=0.0423
#   epoch 25 step 36/72 loss=0.0421
#   epoch 25 step 48/72 loss=0.0423
#   epoch 25 step 60/72 loss=0.0423
#   epoch 25 step 72/72 loss=0.0424
# epoch 25: loss=0.0424 val_ndcg@10=0.0659 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 26 step 12/72 loss=0.0404
#   epoch 26 step 24/72 loss=0.0401
#   epoch 26 step 36/72 loss=0.0403
#   epoch 26 step 48/72 loss=0.0404
#   epoch 26 step 60/72 loss=0.0406
#   epoch 26 step 72/72 loss=0.0405
# epoch 26: loss=0.0405 val_ndcg@10=0.0680 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 27 step 12/72 loss=0.0389
#   epoch 27 step 24/72 loss=0.0387
#   epoch 27 step 36/72 loss=0.0388
#   epoch 27 step 48/72 loss=0.0389
#   epoch 27 step 60/72 loss=0.0389
#   epoch 27 step 72/72 loss=0.0390
# epoch 27: loss=0.0390 val_ndcg@10=0.0710 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 28 step 12/72 loss=0.0375
#   epoch 28 step 24/72 loss=0.0374
#   epoch 28 step 36/72 loss=0.0374
#   epoch 28 step 48/72 loss=0.0374
#   epoch 28 step 60/72 loss=0.0375
#   epoch 28 step 72/72 loss=0.0375
# epoch 28: loss=0.0375 val_ndcg@10=0.0705 time=0.6s
#   epoch 29 step 12/72 loss=0.0359
#   epoch 29 step 24/72 loss=0.0356
#   epoch 29 step 36/72 loss=0.0357
#   epoch 29 step 48/72 loss=0.0358
#   epoch 29 step 60/72 loss=0.0359
#   epoch 29 step 72/72 loss=0.0359
# epoch 29: loss=0.0359 val_ndcg@10=0.0723 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 30 step 12/72 loss=0.0343
#   epoch 30 step 24/72 loss=0.0344
#   epoch 30 step 36/72 loss=0.0344
#   epoch 30 step 48/72 loss=0.0345
#   epoch 30 step 60/72 loss=0.0345
#   epoch 30 step 72/72 loss=0.0347
# epoch 30: loss=0.0347 val_ndcg@10=0.0726 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 31 step 12/72 loss=0.0334
#   epoch 31 step 24/72 loss=0.0333
#   epoch 31 step 36/72 loss=0.0333
#   epoch 31 step 48/72 loss=0.0333
#   epoch 31 step 60/72 loss=0.0334
#   epoch 31 step 72/72 loss=0.0335
# epoch 31: loss=0.0335 val_ndcg@10=0.0745 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 32 step 12/72 loss=0.0322
#   epoch 32 step 24/72 loss=0.0320
#   epoch 32 step 36/72 loss=0.0322
#   epoch 32 step 48/72 loss=0.0322
#   epoch 32 step 60/72 loss=0.0324
#   epoch 32 step 72/72 loss=0.0324
# epoch 32: loss=0.0324 val_ndcg@10=0.0762 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 33 step 12/72 loss=0.0309
#   epoch 33 step 24/72 loss=0.0309
#   epoch 33 step 36/72 loss=0.0310
#   epoch 33 step 48/72 loss=0.0311
#   epoch 33 step 60/72 loss=0.0312
#   epoch 33 step 72/72 loss=0.0313
# epoch 33: loss=0.0313 val_ndcg@10=0.0774 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 34 step 12/72 loss=0.0298
#   epoch 34 step 24/72 loss=0.0298
#   epoch 34 step 36/72 loss=0.0300
#   epoch 34 step 48/72 loss=0.0299
#   epoch 34 step 60/72 loss=0.0299
#   epoch 34 step 72/72 loss=0.0300
# epoch 34: loss=0.0300 val_ndcg@10=0.0766 time=0.6s
#   epoch 35 step 12/72 loss=0.0296
#   epoch 35 step 24/72 loss=0.0294
#   epoch 35 step 36/72 loss=0.0293
#   epoch 35 step 48/72 loss=0.0294
#   epoch 35 step 60/72 loss=0.0294
#   epoch 35 step 72/72 loss=0.0294
# epoch 35: loss=0.0294 val_ndcg@10=0.0780 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 36 step 12/72 loss=0.0286
#   epoch 36 step 24/72 loss=0.0282
#   epoch 36 step 36/72 loss=0.0284
#   epoch 36 step 48/72 loss=0.0283
#   epoch 36 step 60/72 loss=0.0283
#   epoch 36 step 72/72 loss=0.0284
# epoch 36: loss=0.0284 val_ndcg@10=0.0782 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 37 step 12/72 loss=0.0277
#   epoch 37 step 24/72 loss=0.0276
#   epoch 37 step 36/72 loss=0.0275
#   epoch 37 step 48/72 loss=0.0277
#   epoch 37 step 60/72 loss=0.0277
#   epoch 37 step 72/72 loss=0.0277
# epoch 37: loss=0.0277 val_ndcg@10=0.0785 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 38 step 12/72 loss=0.0262
#   epoch 38 step 24/72 loss=0.0264
#   epoch 38 step 36/72 loss=0.0267
#   epoch 38 step 48/72 loss=0.0266
#   epoch 38 step 60/72 loss=0.0267
#   epoch 38 step 72/72 loss=0.0268
# epoch 38: loss=0.0268 val_ndcg@10=0.0796 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 39 step 12/72 loss=0.0260
#   epoch 39 step 24/72 loss=0.0261
#   epoch 39 step 36/72 loss=0.0262
#   epoch 39 step 48/72 loss=0.0261
#   epoch 39 step 60/72 loss=0.0261
#   epoch 39 step 72/72 loss=0.0261
# epoch 39: loss=0.0261 val_ndcg@10=0.0795 time=0.6s
#   epoch 40 step 12/72 loss=0.0252
#   epoch 40 step 24/72 loss=0.0251
#   epoch 40 step 36/72 loss=0.0252
#   epoch 40 step 48/72 loss=0.0254
#   epoch 40 step 60/72 loss=0.0254
#   epoch 40 step 72/72 loss=0.0254
# epoch 40: loss=0.0254 val_ndcg@10=0.0798 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 41 step 12/72 loss=0.0247
#   epoch 41 step 24/72 loss=0.0248
#   epoch 41 step 36/72 loss=0.0248
#   epoch 41 step 48/72 loss=0.0248
#   epoch 41 step 60/72 loss=0.0249
#   epoch 41 step 72/72 loss=0.0249
# epoch 41: loss=0.0249 val_ndcg@10=0.0816 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 42 step 12/72 loss=0.0237
#   epoch 42 step 24/72 loss=0.0239
#   epoch 42 step 36/72 loss=0.0240
#   epoch 42 step 48/72 loss=0.0241
#   epoch 42 step 60/72 loss=0.0242
#   epoch 42 step 72/72 loss=0.0242
# epoch 42: loss=0.0242 val_ndcg@10=0.0814 time=0.6s
#   epoch 43 step 12/72 loss=0.0234
#   epoch 43 step 24/72 loss=0.0234
#   epoch 43 step 36/72 loss=0.0235
#   epoch 43 step 48/72 loss=0.0237
#   epoch 43 step 60/72 loss=0.0237
#   epoch 43 step 72/72 loss=0.0238
# epoch 43: loss=0.0238 val_ndcg@10=0.0810 time=0.6s
#   epoch 44 step 12/72 loss=0.0229
#   epoch 44 step 24/72 loss=0.0231
#   epoch 44 step 36/72 loss=0.0231
#   epoch 44 step 48/72 loss=0.0231
#   epoch 44 step 60/72 loss=0.0232
#   epoch 44 step 72/72 loss=0.0232
# epoch 44: loss=0.0232 val_ndcg@10=0.0815 time=0.6s
#   epoch 45 step 12/72 loss=0.0226
#   epoch 45 step 24/72 loss=0.0226
#   epoch 45 step 36/72 loss=0.0225
#   epoch 45 step 48/72 loss=0.0225
#   epoch 45 step 60/72 loss=0.0226
#   epoch 45 step 72/72 loss=0.0226
# epoch 45: loss=0.0226 val_ndcg@10=0.0818 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 46 step 12/72 loss=0.0224
#   epoch 46 step 24/72 loss=0.0221
#   epoch 46 step 36/72 loss=0.0221
#   epoch 46 step 48/72 loss=0.0222
#   epoch 46 step 60/72 loss=0.0222
#   epoch 46 step 72/72 loss=0.0223
# epoch 46: loss=0.0223 val_ndcg@10=0.0827 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 47 step 12/72 loss=0.0214
#   epoch 47 step 24/72 loss=0.0215
#   epoch 47 step 36/72 loss=0.0217
#   epoch 47 step 48/72 loss=0.0218
#   epoch 47 step 60/72 loss=0.0218
#   epoch 47 step 72/72 loss=0.0217
# epoch 47: loss=0.0217 val_ndcg@10=0.0831 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 48 step 12/72 loss=0.0213
#   epoch 48 step 24/72 loss=0.0210
#   epoch 48 step 36/72 loss=0.0210
#   epoch 48 step 48/72 loss=0.0211
#   epoch 48 step 60/72 loss=0.0212
#   epoch 48 step 72/72 loss=0.0212
# epoch 48: loss=0.0212 val_ndcg@10=0.0818 time=0.6s
#   epoch 49 step 12/72 loss=0.0203
#   epoch 49 step 24/72 loss=0.0204
#   epoch 49 step 36/72 loss=0.0206
#   epoch 49 step 48/72 loss=0.0208
#   epoch 49 step 60/72 loss=0.0208
#   epoch 49 step 72/72 loss=0.0208
# epoch 49: loss=0.0208 val_ndcg@10=0.0825 time=0.6s
#   epoch 50 step 12/72 loss=0.0205
#   epoch 50 step 24/72 loss=0.0205
#   epoch 50 step 36/72 loss=0.0205
#   epoch 50 step 48/72 loss=0.0205
#   epoch 50 step 60/72 loss=0.0205
#   epoch 50 step 72/72 loss=0.0205
# epoch 50: loss=0.0205 val_ndcg@10=0.0848 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 51 step 12/72 loss=0.0199
#   epoch 51 step 24/72 loss=0.0199
#   epoch 51 step 36/72 loss=0.0199
#   epoch 51 step 48/72 loss=0.0200
#   epoch 51 step 60/72 loss=0.0201
#   epoch 51 step 72/72 loss=0.0202
# epoch 51: loss=0.0202 val_ndcg@10=0.0855 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 52 step 12/72 loss=0.0193
#   epoch 52 step 24/72 loss=0.0192
#   epoch 52 step 36/72 loss=0.0194
#   epoch 52 step 48/72 loss=0.0195
#   epoch 52 step 60/72 loss=0.0196
#   epoch 52 step 72/72 loss=0.0197
# epoch 52: loss=0.0197 val_ndcg@10=0.0851 time=0.6s
#   epoch 53 step 12/72 loss=0.0191
#   epoch 53 step 24/72 loss=0.0193
#   epoch 53 step 36/72 loss=0.0192
#   epoch 53 step 48/72 loss=0.0194
#   epoch 53 step 60/72 loss=0.0194
#   epoch 53 step 72/72 loss=0.0195
# epoch 53: loss=0.0195 val_ndcg@10=0.0846 time=0.6s
#   epoch 54 step 12/72 loss=0.0189
#   epoch 54 step 24/72 loss=0.0191
#   epoch 54 step 36/72 loss=0.0190
#   epoch 54 step 48/72 loss=0.0190
#   epoch 54 step 60/72 loss=0.0189
#   epoch 54 step 72/72 loss=0.0190
# epoch 54: loss=0.0190 val_ndcg@10=0.0841 time=0.6s
#   epoch 55 step 12/72 loss=0.0187
#   epoch 55 step 24/72 loss=0.0186
#   epoch 55 step 36/72 loss=0.0186
#   epoch 55 step 48/72 loss=0.0187
#   epoch 55 step 60/72 loss=0.0186
#   epoch 55 step 72/72 loss=0.0188
# epoch 55: loss=0.0188 val_ndcg@10=0.0859 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 56 step 12/72 loss=0.0181
#   epoch 56 step 24/72 loss=0.0183
#   epoch 56 step 36/72 loss=0.0184
#   epoch 56 step 48/72 loss=0.0184
#   epoch 56 step 60/72 loss=0.0186
#   epoch 56 step 72/72 loss=0.0186
# epoch 56: loss=0.0186 val_ndcg@10=0.0848 time=0.6s
#   epoch 57 step 12/72 loss=0.0181
#   epoch 57 step 24/72 loss=0.0180
#   epoch 57 step 36/72 loss=0.0180
#   epoch 57 step 48/72 loss=0.0181
#   epoch 57 step 60/72 loss=0.0182
#   epoch 57 step 72/72 loss=0.0183
# epoch 57: loss=0.0183 val_ndcg@10=0.0859 time=0.6s
#   epoch 58 step 12/72 loss=0.0173
#   epoch 58 step 24/72 loss=0.0173
#   epoch 58 step 36/72 loss=0.0176
#   epoch 58 step 48/72 loss=0.0177
#   epoch 58 step 60/72 loss=0.0178
#   epoch 58 step 72/72 loss=0.0177
# epoch 58: loss=0.0177 val_ndcg@10=0.0865 time=0.6s
#   -> new best, saved /content/music-recommendations/artifacts/gsasrec/best.pt
#   epoch 59 step 12/72 loss=0.0171
#   epoch 59 step 24/72 loss=0.0175
#   epoch 59 step 36/72 loss=0.0175
#   epoch 59 step 48/72 loss=0.0176
#   epoch 59 step 60/72 loss=0.0176
#   epoch 59 step 72/72 loss=0.0177
# epoch 59: loss=0.0177 val_ndcg@10=0.0863 time=0.6s
# {'best_ndcg': 0.0865479850205558,
#  'checkpoint': '/content/music-recommendations/artifacts/gsasrec/best.pt',
#  'metrics_csv': '/content/music-recommendations/artifacts/gsasrec/metrics.csv',
#  'config_json': '/content/music-recommendations/artifacts/gsasrec/config.json'}

# %% [markdown]
# ## 3. Sanity-check: загрузка чекпоинта

# %%
from src.scorer.inference import load_checkpoint


model, mcfg = load_checkpoint(result['checkpoint'], device=cfg.device)
n_params = sum(p.numel() for p in model.parameters())
print(f'loaded model, {n_params/1e6:.2f}M params, ckpt cfg n_items={mcfg["n_items"]}')
# Out:
# loaded model, 17.80M params, ckpt cfg n_items=276305

# %%
# Также сохраним item_id_to_idx рядом с чекпоинтом — потребуется в inference и в Phase 2.
from src.utils.caching import save_pickle


save_pickle(item_id_to_idx, PROJECT_ROOT / 'artifacts' / 'gsasrec' / 'item_id_to_idx.pkl')
print('saved item_id_to_idx.pkl')
# Out:
# saved item_id_to_idx.pkl

# %% [markdown]
# ## 4. Просмотр кривой обучения

# %%
import pandas as pd
import matplotlib.pyplot as plt


metrics = pd.read_csv(result['metrics_csv'])
fig, ax1 = plt.subplots(figsize=(7, 4))
ax2 = ax1.twinx()
ax1.plot(metrics['epoch'], metrics['train_loss'], 'b-o', label='train loss')
ax2.plot(metrics['epoch'], metrics[f'val_ndcg@{cfg.eval_k}'], 'r-s', label=f'val NDCG@{cfg.eval_k}')
ax1.set_xlabel('epoch'); ax1.set_ylabel('train loss', color='b'); ax2.set_ylabel(f'val NDCG@{cfg.eval_k}', color='r')
ax1.grid(True, alpha=0.3)
plt.title('gSASRec training')
plt.tight_layout()
plt.show()
metrics.tail()
# Out:
#     epoch  train_loss  val_ndcg@10  epoch_seconds
# 55     55    0.018759     0.085924           0.58
# 56     56    0.018592     0.084844           0.58
# 57     57    0.018260     0.085851           0.58
# 58     58    0.017734     0.086548           0.58
# 59     59    0.017693     0.086316           0.58

# %% [markdown]
# ## 5. Sanity-check на test (per-user NDCG@10, не групповой)
#
# Это диагностика скорера, не финальная оценка диплома (она групповая, Phase 2). Если test ≈ val — модель не переобучилась на val через early stopping.

# %%
from src.scorer.train import build_user_sequences, evaluate_ndcg

train_sequences = build_user_sequences(train, max_seq_len=cfg.max_seq_len)
test_targets = {
    int(uid): set(int(x) for x in g['item_idx'].to_numpy())
    for uid, g in test.groupby('uid', sort=False)
}
common = sum(1 for u in test_targets if u in train_sequences)
print(f'users in test: {len(test_targets)}, with train history: {common}')

test_ndcg = evaluate_ndcg(
    model,
    train_sequences=train_sequences,
    val_targets=test_targets,
    max_seq_len=cfg.max_seq_len,
    n_items=cfg.n_items,
    k=cfg.eval_k,
    batch_size=cfg.eval_batch_size,
    device=cfg.device,
)
print(f'test NDCG@{cfg.eval_k} = {test_ndcg:.4f}  (best val NDCG@{cfg.eval_k} = {result["best_ndcg"]:.4f})')
# Out:
# users in test: 4576, with train history: 4576
# test NDCG@10 = 0.0726  (best val NDCG@10 = 0.0865)

# %% [markdown]
# ## 6. Cache per-user top-K scores (Phase 1, Step I)
#
# Прогоняем уже обученный gSASRec для всех train-пользователей и сохраняем топ-K кандидатов со скорами. Этот кэш используется в Phase 2 — групповые агрегаторы читают `s_{u,i}` отсюда, а не дёргают gSASRec на каждом батче.
#
# Выход: `artifacts/user_scores_cache/scores.parquet` с колонками `uid:int64, item_idx:int64, score:float32, rank:int32`.
#
# Эту секцию можно запускать отдельно после переобучения — `model`, `train_sequences`, `n_items`, `cfg.max_seq_len` уже в памяти.

# %%
from src.scorer.inference import cache_user_scores, InferenceConfig

K = 200  # запас для Phase 2; агрегаторы будут резать по своим |C_G|
out_path = PROJECT_ROOT / 'artifacts' / 'user_scores_cache' / 'scores.parquet'

inf_cfg = InferenceConfig(K=K, batch_size=128, exclude_history=True, device=cfg.device)
cache_user_scores(model, train_sequences, cfg.max_seq_len, n_items, out_path, inf_cfg)
print('saved:', out_path)

# %%
scores = pd.read_parquet(out_path)
print('rows:', len(scores))
print('users:', scores.uid.nunique())
print(f'K per user (should be {K}):', scores.groupby('uid').size().unique())
print('rank range:', scores['rank'].min(), '..', scores['rank'].max())
print('score range:', float(scores.score.min()), '..', float(scores.score.max()))
scores.head(10)
